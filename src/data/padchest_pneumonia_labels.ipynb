# %% [markdown]
# #### This notebook filters images with 'Labels'= 'pneumonia/normal' from the Padchest dataset.

# %% [markdown]
# 'padchest_normal_pneumonia.csv' was provided by Wafa. It conteins 'ImagesID' with 'Labels'='pneumonia/normal'.
#
# Images part were downloaded from https://www.kaggle.com/datasets/chandanverma/padchest. Images include not only pneumonia labels.
#
# The task is to filter the images by their names corresponding 'ImagesID' in 'padchest_normal_pneumonia.csv' for further work with the sample of pneumonia/normal images and text notes.

# %% [markdown]
# ### Import libraries

# %%
import os
import shutil
import pandas as pd

# %% [markdown]
# ### Import data

# %%
df = pd.read_csv('padchest_normal_pneumonia.csv')
df.head()
# Out:
#                                              ImageID PatientSex_DICOM  \
# 0  20536686640136348236148679891455886468_k6ga29.png                F
# 1  238285621348398466668514178112618553012_a7k6dv...                F
# 2  152191969602076825998375638267191596461_ck9qkz...                F
# 3  84289138814897824414670894017743137660_xjsw7k.png                F
# 4  243837679625088918208093479515843617254_zotvy7...                F
#
#   ViewPosition_DICOM                                             Report  \
# 0    POSTEROANTERIOR                   no finding pathology patient age
# 1    POSTEROANTERIOR                without alter radiolog significance
# 2    POSTEROANTERIOR                no significant radiological finding
# 3    POSTEROANTERIOR                                             normal
# 4            LATERAL  Siluet cardiomediastin within normal lung pare...
#
#   MethodLabel  Labels                              Localizations  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7977 entries, 0 to 7976
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ImageID                        7977 non-null   object
#  1   PatientSex_DICOM               7977 non-null   object
#  2   ViewPosition_DICOM             7977 non-null   object
#  3   Report                         7974 non-null   object
#  4   MethodLabel                    7977 non-null   object
#  5   Labels                         7977 non-null   object
#  6   Localizations                  7977 non-null   object
#  7   LabelsLocalizationsBySentence  7977 non-null   object
#  8   PatientAge                     7977 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 561.0+ KB

# %%
# extract images downloaded from kaggle

# importing the zipfile module 
#from zipfile import ZipFile
  
# loading the temp.zip and creating a zip object
#with ZipFile("C:\\Users\\Kseniya\\Omdena\\MMML\\padchest\\archive.zip", 'r') as zObject:
  
    # Extracting all the members of the zip 
    # into a specific location.
    #zObject.extractall(
        #path="C:\\Users\\Kseniya\\Omdena\\MMML\\padchest\\images")

# %% [markdown]
# ### Filter images

# %%
# create a list of 'ImageID' to compare with images names

id_list = df['ImageID'].values.tolist()
id_list
# Out:
# ['20536686640136348236148679891455886468_k6ga29.png',
#  '238285621348398466668514178112618553012_a7k6dv.png',
#  '152191969602076825998375638267191596461_ck9qkz.png',
#  '84289138814897824414670894017743137660_xjsw7k.png',
#  '243837679625088918208093479515843617254_zotvy7.png',
#  '243837679625088918208093479515843617254_znbkkx.png',
#  '337234085099221143119428528401779812468_1hc03o.png',
#  '337234085099221143119428528401779812468_1hfc86.png',
#  '12582988208641810053552022080964044412_bdbfde.png',
#  '151619064599028082995709172863126236342_adr7uc.png',
#  '173348027872651650413607534885352239722_ksfbkd.png',
#  '173348027872651650413607534885352239722_ksfbkb.png',
#  '267593312931260619142226905522973356507_dfimnx.png',
#  '105591880985588572332898967525311229749_yqjtuk.png',
#  '330324745759424821132494701991767497957_9fc9au.png',
#  '175828040998318011818448557383860207677_m5a8ih.png',
#  '101408931302974623103956952273007774313_9stb1v.png',
# ...

# %%
len(id_list)
# Out:
# 7977

# %%
# get the filenames of the images

for root, dirs, files in os.walk("./images/images-224"):  
    for filename in files:
        print(filename)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 216840111366964013829543166512013323102254421_02-112-130.png
# 216840111366964013829543166512013323104324523_02-110-187.png
# 216840111366964013829543166512013323104324523_02-110-188.png
# 216840111366964013829543166512013323104429304_02-116-021.png
# 216840111366964013829543166512013323105552299_02-110-186.png
# 216840111366964013829543166512013323105552299_02-111-000.png
# 216840111366964013829543166512013323110506905_02-108-010.png
# 216840111366964013829543166512013323111032825_02-112-127.png
# 216840111366964013829543166512013323112149041_02-115-112.png
# 216840111366964013829543166512013323112317428_02-112-021.png
# ...

# %%
# create new folder for the relevant images

#main_path = 'C:\\Users\\Kseniya\\Omdena\\MMML\\padchest\\images'
#os.mkdir(main_path + '\\pneumonia')

# %%
# if an image name presents in the 'ImageID' list from csv with text notes, move the image to the created folder

for root, dirs, files in os.walk("./images/images-224"):  
    for filename in files:
        if filename in names_list:
            shutil.move(f'./images/images-224/{filename}', f'./images/pneumonia/{filename}')
